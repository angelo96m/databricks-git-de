# %%
# %python

# %%
df = (spark.read.table("trips_result"))

# %%
df.printSchema

# %%
df.count()

# %%
df.filter(df.service_type == "green").count()

# %%
df.filter(df.service_type == "yellow").count()

# %%
df.filter(df.revenue_monthly_fare >= 100).filter(df.service_type == "yellow").count()
